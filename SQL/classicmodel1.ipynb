# %%
# !cd
# Out:
# C:\Users\i\Desktop\2021-K-Digital-Training-main\SQL

# %%
import pymysql.cursors

# %%
import pandas as pd

# %%
connection = pymysql.connect(host='localhost', 
        user='me',
        password='127984',
        db='classicmodels',
        charset='utf8',
        cursorclass=pymysql.cursors.DictCursor) # localhost

sql = 'select customers.customerNumber, customers.salesRepEmployeeNumber, payments.checkNumber from customers LEFT JOIN payments on customers.customerNumber = payments.customerNumber;'

try:
    with connection.cursor() as cursor:
        # Read a single record
        #sql = "SELECT `id`, `password` FROM `users` WHERE `email`=%s"
        #sql = "SELECT total_bill FROM tip.tips where tip >= 7 ;"
        #sql = "SELECT count(total_bill) FROM tip.tips where tip >= 7 ;"
        cursor.execute(sql)
        result = cursor.fetchall()
        df= pd.DataFrame(result)
        #print(result)
finally:
    connection.close()

# %%
df.isnull().sum()

# %%
df.values

# %%
data = df.values
ix = [i for i in range(data.shape[1]) if i != 3]

# %%
X = data[:,:1]

# %%
X

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# fit on the dataset
imputer.fit(X)

# transform the dataset
Xtrans = imputer.transform(X)

# %%
Xtrans
# Out:
# array([[125.],
#        [169.],
#        [206.],
#        [223.],
#        [237.],
#        [247.],
#        [273.],
#        [293.],
#        [303.],
#        [307.],
#        [335.],
#        [348.],
#        [356.],
#        [361.],
#        [369.],
#        [409.],
#        [443.],
#        [459.],
#        [465.],
#        [477.],
#        [480.],
#        [481.],
#        [124.],
#        [124.],
#        [124.],
#        [124.],
#        [124.],
#        [124.],
#        [124.],
#        [124.],
#        [124.],
#        [129.],
#        [129.],
#        [129.],
#        [161.],
#        [161.],
#        [161.],
#        [161.],
#        [321.],
#        [321.],
#        [450.],
#        [487.],
#        [487.],
#        [112.],
#        [112.],
#        [112.],
#        [205.],
#        [205.],
#        [205.],
#        [219.],
#        [219.],
#        [239.],
#        [347.],
#        [347.],
#        [475.],
#        [475.],
#        [173.],
#        [173.],
#        [204.],
#        [204.],
#        [320.],
#        [320.],
#        [320.],
#        [339.],
#        [339.],
#        [379.],
#        [379.],
#        [379.],
#        [495.],
#        [495.],
#        [157.],
#        [157.],
#        [198.],
#        [198.],
#        [198.],
#        [286.],
#        [286.],
#        [362.],
#        [362.],
#        [363.],
#        [363.],
#        [363.],
#        [462.],
#        [462.],
#        [462.],
#        [151.],
#        [151.],
#        [151.],
#        [151.],
#        [168.],
#        [181.],
#        [181.],
#        [181.],
#        [233.],
#        [233.],
#        [233.],
#        [424.],
#        [424.],
#        [424.],
#        [455.],
#        [455.],
#        [456.],
#        [456.],
#        [131.],
#        [131.],
#        [131.],
#        [175.],
#        [175.],
#        [175.],
#        [202.],
#        [202.],
#        [260.],
#        [260.],
#        [319.],
#        [319.],
#        [328.],
#        [328.],
#        [447.],
#        [447.],
#        [447.],
#        [486.],
#        [486.],
#        [486.],
#        [146.],
#        [146.],
#        [146.],
#        [172.],
#        [172.],
#        [172.],
#        [250.],
#        [250.],
#        [250.],
#        [350.],
#        [350.],
#        [350.],
#        [353.],
#        [353.],
#        [353.],
#        [353.],
#        [406.],
#        [406.],
#        [406.],
#        [103.],
#        [103.],
#        [103.],
#        [119.],
#        [119.],
#        [119.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [141.],
#        [171.],
#        [171.],
#        [209.],
#        [209.],
#        [209.],
#        [242.],
#        [242.],
#        [242.],
#        [256.],
#        [256.],
#        [145.],
#        [145.],
#        [145.],
#        [145.],
#        [227.],
#        [227.],
#        [249.],
#        [249.],
#        [278.],
#        [278.],
#        [278.],
#        [314.],
#        [314.],
#        [381.],
#        [381.],
#        [381.],
#        [381.],
#        [382.],
#        [382.],
#        [382.],
#        [386.],
#        [386.],
#        [452.],
#        [452.],
#        [452.],
#        [473.],
#        [473.],
#        [186.],
#        [186.],
#        [186.],
#        [187.],
#        [187.],
#        [187.],
#        [201.],
#        [201.],
#        [240.],
#        [240.],
#        [311.],
#        [311.],
#        [311.],
#        [324.],
#        [324.],
#        [324.],
#        [334.],
#        [334.],
#        [334.],
#        [489.],
#        [489.],
#        [121.],
#        [121.],
#        [121.],
#        [121.],
#        [128.],
#        [128.],
#        [128.],
#        [128.],
#        [144.],
#        [144.],
#        [167.],
#        [167.],
#        [189.],
#        [189.],
#        [259.],
#        [259.],
#        [299.],
#        [299.],
#        [415.],
#        [448.],
#        [448.],
#        [114.],
#        [114.],
#        [114.],
#        [114.],
#        [276.],
#        [276.],
#        [276.],
#        [276.],
#        [282.],
#        [282.],
#        [282.],
#        [333.],
#        [333.],
#        [333.],
#        [471.],
#        [471.],
#        [166.],
#        [166.],
#        [166.],
#        [323.],
#        [323.],
#        [323.],
#        [323.],
#        [357.],
#        [357.],
#        [412.],
#        [412.],
#        [496.],
#        [496.],
#        [496.],
#        [148.],
#        [148.],
#        [148.],
#        [148.],
#        [177.],
#        [177.],
#        [211.],
#        [385.],
#        [385.],
#        [385.],
#        [398.],
#        [398.],
#        [398.],
#        [398.],
#        [216.],
#        [216.],
#        [216.],
#        [298.],
#        [298.],
#        [344.],
#        [344.],
#        [376.],
#        [458.],
#        [458.],
#        [458.],
#        [484.],
#        [484.]])

# %%
from numpy import isnan

# %%
# print total missing
#print('Missing: %d' % sum(isnan(X).flatten()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2e618574833b> in <module>
#       1 # print total missing
# ----> 2 print('Missing: %d' % sum(isnan(X).flatten()))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
